# %%
import pandas as pd

df = pd.read_csv("tp_conv.tsv", sep='\t')
# df.drop("index", axis="columns", inplace=True)
# Out:
#    num_touchpoints  num_conversions
# 0                2          10819.0
# 1                1          10946.0
# 2                3           2817.0
# 3                4           1754.0
# 4                5           1197.0

# %%
df.plot.scatter('num_touchpoints', 'num_conversions')
# Out:
# <Axes: xlabel='num_touchpoints', ylabel='num_conversions'>

# %%
df2 = pd.read_csv("chan_conv.csv", sep='\t')
df2
# Out:
#         default_channel_group   conversions
# 0              Organic Search  15238.715750
# 1                 Paid Search   7970.363212
# 2                      Direct   2999.000000
# 3              Organic Social   1505.144646
# 4                    Referral   1461.769686
# 5                       Email   1044.508931
# 6                 Paid Social    920.349988
# 7                  Unassigned    242.530930
# 8                     Display    167.555387
# 9               Cross-network    115.839248
# 10  Mobile Push Notifications      5.222222
# 11                 Paid Other      1.000000

# %%
df2.plot.bar(y='conversions', x='default_channel_group')
# Out:
# <Axes: xlabel='default_channel_group'>
