# %%
from query_data import DataFetch

data_store = DataFetch()

try: 
    tp_conv = data_store.get_data('tp_conv')
    con_per_p = data_store.get_data('con_per_p')
    agg_conn_type = data_store.get_data('agg_conn_type')
    chan_conv = data_store.get_data('chan_conv')
except Exception as err:
    print(err)

# %%
agg_conn_type
# Out:
#    conversion_rate_total  conversion_rate_per_user  views_per_user   ptype
# 0                 0.0428                    0.0946       65.938450  RESORT
# 1                 0.1474                    0.2267        8.283078   HOTEL
# 2                 0.0031                    0.0045       10.210306    None
# 3                 0.1186                    0.1855        3.125496  DINING
# 4                 0.4256                    0.6057        4.307135  OFFERS

# %%
con_per_p
# Out:
#                                                  page  conversion_rate_total  \
# 0   Faro Blanco Resort Yacht Club - Reservations -...                 0.0000
# 1   Hotels In Marathon FL | Faro Blanco Resort & M...                 0.1313
# 2   Faro Blanco Resort | Resorts in Marathon FL | ...                 0.1039
# 3                                           (not set)                 0.0000
# 4   Faro Blanco Resort Yacht Club - Reservations -...                 0.0541
# ..                                                ...                    ...
# 58           Groups | Faro Blanco Resort & Yacht Club                 0.0288
# 59  Marathon FL Family Resorts | Privacy Policy | ...                 0.0370
# 60  Marathon Wedding Venues | Faro Blanco Resort &...                 0.0000
# 61  Faro Blanco Resort Yacht Club - Reservations -...                 0.0000
# 62  Balneario Faro Blanco | Hoteles en Marathon FL...                 0.0000
#
#     conversion_rate_per_user  views_per_user
# ...

# %%
chan_conv
# Out:
#         default_channel_group   conversions
# 0              Organic Search  15238.715750
# 1                 Paid Search   7970.363212
# 2                      Direct   2999.000000
# 3              Organic Social   1505.144646
# 4                    Referral   1461.769686
# 5                       Email   1044.508931
# 6                 Paid Social    920.349988
# 7                  Unassigned    242.530930
# 8                     Display    167.555387
# 9               Cross-network    115.839248
# 10  Mobile Push Notifications      5.222222
# 11                 Paid Other      1.000000

# %%
tp_conv
# Out:
#     num_touchpoints  num_conversions
# 0                 2          10819.0
# 1                 1          10946.0
# 2                 3           2817.0
# 3                 4           1754.0
# 4                 5           1197.0
# 5                 6            792.0
# 6                50            379.0
# 7                 7            503.0
# 8                 8            383.0
# 9                 9            261.0
# 10               10            244.0
# 11               11            179.0
# 12               12            173.0
# 13               13            109.0
# 14               14            134.0
# 15               16             81.0
# 16               15             90.0
# 17               17             84.0
# 18               29             54.0
# 19               18             47.0
# 20               20             58.0
# 21               19             76.0
# 22               25             35.0
# 23               24             37.0
# ...
